# %%
# !pip install smolagents huggingface_hub ddgs -U

# %%
from smolagents import tool

@tool
def suggest_menu(country: str) -> str:
    """
    Suggest a themed party menu based on a country's cuisine.

    Args:
        country: Name of the country whose cuisine should be used.
    """

    country_aliases = {
        "Tokyo": "Japan",
        "Kyoto": "Japan",
        "Osaka": "Japan",
        "Paris": "France",
        "London": "United Kingdom",
        "Seoul": "South Korea",
        "Bangkok": "Thailand",
        "Rome": "Italy",
        "New York": "USA"
    }

    country = country.strip().title()
    country = country_aliases.get(country, country)

    menus = {

        "India": """
Country: India
Theme: Royal Indian Feast

Appetizer: Paneer Tikka
Main Course: Hyderabadi Biryani
Dessert: Gulab Jamun
Beverage: Masala Chai

Fun Fact:
India is known for its incredible diversity of regional cuisines.
""",

        "Japan": """
Country: Japan
Theme: Tokyo Night Festival

Appetizer: Edamame
Main Course: Sushi Platter
Dessert: Mochi
Beverage: Matcha Tea

Fun Fact:
Japan combines traditional culinary techniques with modern presentation.
""",

        "Italy": """
Country: Italy
Theme: Venetian Dinner Party

Appetizer: Bruschetta
Main Course: Pasta Carbonara
Dessert: Tiramisu
Beverage: Italian Soda

Fun Fact:
Italian cuisine emphasizes fresh ingredients and simplicity.
""",

        "China": """
Country: China
Theme: Dragon Banquet

Appetizer: Dumplings
Main Course: Kung Pao Chicken
Dessert: Mooncake
Beverage: Jasmine Tea

Fun Fact:
Chinese cuisine has over 5,000 years of history.
""",

        "France": """
Country: France
Theme: Parisian Evening

Appetizer: French Onion Soup
Main Course: Coq au Vin
Dessert: Creme Brulee
Beverage: Sparkling Water

Fun Fact:
French cuisine heavily influenced modern fine dining.
""",

        "Spain": """
Country: Spain
Theme: Barcelona Fiesta

Appetizer: Patatas Bravas
Main Course: Paella
Dessert: Churros
Beverage: Sangria

Fun Fact:
Paella originated in Valencia.
""",

        "Thailand": """
Country: Thailand
Theme: Bangkok Street Feast

Appetizer: Spring Rolls
Main Course: Pad Thai
Dessert: Mango Sticky Rice
Beverage: Thai Iced Tea

Fun Fact:
Thai cuisine balances sweet, sour, salty and spicy flavors.
""",

        "South Korea": """
Country: South Korea
Theme: Seoul Food Festival

Appetizer: Kimchi
Main Course: Bibimbap
Dessert: Hotteok
Beverage: Barley Tea

Fun Fact:
Kimchi is a staple in Korean cuisine.
""",

        "Turkey": """
Country: Turkey
Theme: Istanbul Night

Appetizer: Mezze Platter
Main Course: Kebab
Dessert: Baklava
Beverage: Turkish Tea

Fun Fact:
Turkey bridges European and Asian culinary traditions.
""",

        "Greece": """
Country: Greece
Theme: Santorini Gathering

Appetizer: Greek Salad
Main Course: Moussaka
Dessert: Baklava
Beverage: Lemonade

Fun Fact:
Olive oil is central to Greek cooking.
""",

        "Germany": """
Country: Germany
Theme: Oktoberfest Feast

Appetizer: Pretzel
Main Course: Bratwurst
Dessert: Black Forest Cake
Beverage: Apple Juice

Fun Fact:
Germany is famous for hundreds of bread varieties.
""",

        "Brazil": """
Country: Brazil
Theme: Rio Celebration

Appetizer: Pao de Queijo
Main Course: Feijoada
Dessert: Brigadeiro
Beverage: Guarana

Fun Fact:
Brazilian cuisine reflects Indigenous, African and Portuguese influences.
""",

        "Usa": """
Country: USA
Theme: American Backyard Party

Appetizer: Buffalo Wings
Main Course: BBQ Ribs
Dessert: Cheesecake
Beverage: Lemonade

Fun Fact:
Regional cuisines vary greatly across the United States.
""",

        "United Kingdom": """
Country: United Kingdom
Theme: London Tea Gathering

Appetizer: Scotch Eggs
Main Course: Fish and Chips
Dessert: Sticky Toffee Pudding
Beverage: English Breakfast Tea

Fun Fact:
Afternoon tea became popular in the 1840s.
""",

        "Mexico": """
Country: Mexico
Theme: Fiesta Night

Appetizer: Nachos
Main Course: Street Tacos
Dessert: Churros
Beverage: Horchata

Fun Fact:
Mexican cuisine is recognized by UNESCO as cultural heritage.
"""
    }

    return menus.get(
        country,
        f"Sorry, no menu is available for {country}."
    )

# %%
menus = {

    "India": """
Country: India
Theme: Royal Indian Feast

Appetizer: Paneer Tikka
Main Course: Hyderabadi Biryani
Dessert: Gulab Jamun
Beverage: Masala Chai

Fun Fact:
India is known for its incredible diversity of regional cuisines.
""",

    "Italy": """
Country: Italy
Theme: Venetian Dinner Party

Appetizer: Bruschetta
Main Course: Pasta Carbonara
Dessert: Tiramisu
Beverage: Italian Soda

Fun Fact:
Italian cuisine emphasizes fresh ingredients and simplicity.
""",

    "Japan": """
Country: Japan
Theme: Tokyo Night Festival

Appetizer: Edamame
Main Course: Sushi Platter
Dessert: Mochi
Beverage: Matcha Tea

Fun Fact:
Japan combines traditional culinary techniques with modern presentation.
""",

    "China": """
Country: China
Theme: Chinese New Year Banquet

Appetizer: Dumplings
Main Course: Kung Pao Chicken
Dessert: Mooncake
Beverage: Jasmine Tea

Fun Fact:
Chinese cuisine has over 5,000 years of history.
""",

    "Mexico": """
Country: Mexico
Theme: Fiesta Night

Appetizer: Nachos
Main Course: Street Tacos
Dessert: Churros
Beverage: Horchata

Fun Fact:
Mexican cuisine is recognized by UNESCO as cultural heritage.
""",

    "France": """
Country: France
Theme: Parisian Evening

Appetizer: French Onion Soup
Main Course: Coq au Vin
Dessert: Crème Brûlée
Beverage: Sparkling Water

Fun Fact:
French cuisine heavily influenced modern fine dining.
""",

    "Spain": """
Country: Spain
Theme: Mediterranean Celebration

Appetizer: Patatas Bravas
Main Course: Paella
Dessert: Churros
Beverage: Sangria

Fun Fact:
Paella originated in Valencia, Spain.
""",

    "Thailand": """
Country: Thailand
Theme: Bangkok Street Food Festival

Appetizer: Spring Rolls
Main Course: Pad Thai
Dessert: Mango Sticky Rice
Beverage: Thai Iced Tea

Fun Fact:
Thai cuisine balances sweet, sour, salty, and spicy flavors.
""",

    "South Korea": """
Country: South Korea
Theme: Seoul Food Festival

Appetizer: Kimchi
Main Course: Bulgogi
Dessert: Hotteok
Beverage: Barley Tea

Fun Fact:
Kimchi is considered a staple in Korean cuisine.
""",

    "Turkey": """
Country: Turkey
Theme: Ottoman Feast

Appetizer: Meze Platter
Main Course: Kebab
Dessert: Baklava
Beverage: Turkish Tea

Fun Fact:
Turkish cuisine blends influences from Asia and Europe.
""",

    "Greece": """
Country: Greece
Theme: Santorini Sunset Dinner

Appetizer: Greek Salad
Main Course: Moussaka
Dessert: Baklava
Beverage: Lemonade

Fun Fact:
Olive oil is a key ingredient in Greek cuisine.
""",

    "Germany": """
Country: Germany
Theme: Oktoberfest Celebration

Appetizer: Pretzel
Main Course: Bratwurst
Dessert: Black Forest Cake
Beverage: Apple Juice

Fun Fact:
Germany is famous for its breads and sausages.
""",

    "Brazil": """
Country: Brazil
Theme: Rio Carnival Feast

Appetizer: Pão de Queijo
Main Course: Feijoada
Dessert: Brigadeiro
Beverage: Guaraná

Fun Fact:
Feijoada is considered Brazil's national dish.
""",

    "USA": """
Country: USA
Theme: Backyard BBQ Party

Appetizer: Buffalo Wings
Main Course: BBQ Ribs
Dessert: Cheesecake
Beverage: Lemonade

Fun Fact:
Regional cuisines vary greatly across the United States.
""",

    "United Kingdom": """
Country: United Kingdom
Theme: London Tea Gathering

Appetizer: Scotch Eggs
Main Course: Fish and Chips
Dessert: Sticky Toffee Pudding
Beverage: English Breakfast Tea

Fun Fact:
Afternoon tea became popular in the 1840s.
"""
}

# %%
from smolagents import CodeAgent, InferenceClientModel

model = InferenceClientModel(
    model_id="Qwen/Qwen2.5-Coder-32B-Instruct"
)

agent = CodeAgent(
    tools=[suggest_menu],
    model=model
)

# %%
agent.run("Plan a Tokyo themed party")
agent.run("Plan a Paris themed party")
agent.run("Plan a Seoul themed party")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Plan a Tokyo themed party                                                                                       │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen2.5-Coder-32B-Instruct ────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   menu = suggest_menu(country="Japan")
#   print(menu)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ...
